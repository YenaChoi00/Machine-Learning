# %% [markdown]
# <a href="https://colab.research.google.com/github/YenaChoi00/MachineLearning/blob/main/Object_Detection_YOLOv5_pytorch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## YOLOv5 모델 (PyTorch)
#
# * https://github.com/ultralytics/yolov5
# * https://www.ultralytics.com

# %% [markdown]
# # 모델 다운로드

# %%
# %cd /content
# !git clone https://github.com/ultralytics/yolov5
# %cd yolov5
# %pip install -qr requirements.txt

import torch
from IPython.display import Image, clear_output
# Out:
# /content
# Cloning into 'yolov5'...
# remote: Enumerating objects: 15679, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (7/7), done.
# remote: Total 15679 (delta 1), reused 2 (delta 0), pack-reused 15672
# Receiving objects: 100% (15679/15679), 14.45 MiB | 24.83 MiB/s, done.
# Resolving deltas: 100% (10742/10742), done.
# /content/yolov5
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.3/184.3 kB 4.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 586.5/586.5 kB 23.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 7.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 205.1/205.1 kB 18.8 MB/s eta 0:00:00

# %% [markdown]
# # 추론 (Inference)
#
# `detect.py`: Yolo 모델을 이용한 추론

# %%
# !ls data/images
# Out:
# bus.jpg  zidane.jpg

# %%
Image(filename='data/images/bus.jpg', width=500)

# %%
Image(filename='data/images/zidane.jpg', width=500)

# %%
Image(filename='data/images/kid.jpg', width=500)

# %%
# !python detect.py --weights yolov5s.pt --img 640 --conf 0.25 --source data/images/
# Out:
# detect: weights=['yolov5s.pt'], source=data/images/, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# requirements: /usr/local/lib/python3.10/dist-packages/requirements.txt not found, check failed.
# YOLOv5 🚀 v7.0-168-gec2b853 Python-3.10.11 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients
# image 1/3 /content/yolov5/data/images/bus.jpg: 640x480 4 persons, 1 bus, 42.7ms
# image 2/3 /content/yolov5/data/images/kid.jpg: 320x640 4 persons, 1 bus, 1 handbag, 41.3ms
# image 3/3 /content/yolov5/data/images/zidane.jpg: 384x640 2 persons, 2 ties, 46.8ms
# ...

# %%
Image(filename='runs/detect/exp2/kid.jpg', width=500)

# %%
Image(filename='runs/detect/exp2/zidane.jpg', width=500)
