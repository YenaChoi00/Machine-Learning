# %% [markdown]
# <a href="https://colab.research.google.com/github/YenaChoi00/MachineLearning/blob/main/Object_Detection_YOLOv3_pytorch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## YOLOv3 모델 (PyTorch)
#
# * https://github.com/ultralytics/yolov3
# * https://www.ultralytics.com
#
# ** 강의: https://youtu.be/fdWx3QV5n44

# %% [markdown]
# 모델 다운로드

# %%
# !git clone https://github.com/ultralytics/yolov3
# %cd yolov3
# %pip install -qr requirements.txt

import yaml
import torch
from IPython.display import Image, clear_output

# cuda는 GPU 의미
print(f"Torch: {torch.__version__} ({torch.cuda.get_device_properties(0).name if torch.cuda.is_available() else 'CPU'})")
# Out:
# Cloning into 'yolov3'...
# remote: Enumerating objects: 10605, done.
# remote: Counting objects: 100% (527/527), done.
# remote: Compressing objects: 100% (319/319), done.
# remote: Total 10605 (delta 330), reused 381 (delta 207), pack-reused 10078
# Receiving objects: 100% (10605/10605), 9.76 MiB | 32.23 MiB/s, done.
# Resolving deltas: 100% (7129/7129), done.
# /content/yolov3/yolov3
# Torch: 2.0.1+cu118 (CPU)

# %%
#%cd ..
#!rm -rf yolov3

# %% [markdown]
# # 추론 (Inference)
#
# `detect.py` : YOLOv3 모델을 이용한 추론

# %%
# 예제 사진
# !ls data/images
# Out:
# bus.jpg  kid.jpg  zidane.jpg

# %%
Image(filename='data/images/bus.jpg', width=600)

# %%
Image(filename='data/images/zidane.jpg', width=600)

# %%
# 파이썬 파일(detect.py)을 이용- weight값, 이미지 크기, 등을 지정
# !python detect.py --weights yolov3.pt --img 640 --conf 0.25 --source data/images/

# detect가 객체감지한 파일이 저장되는 위치가 끝에 출력된다.
# Out:
# detect: weights=['yolov3.pt'], source=data/images/, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# requirements: /usr/local/lib/python3.10/dist-packages/requirements.txt not found, check failed.
# YOLOv3 🚀 v9.6.0-75-g65d88b1 Python-3.10.11 torch-2.0.1+cu118 CPU
#
# Fusing layers...
# yolov3 summary: 261 layers, 61922845 parameters, 0 gradients
# image 1/3 /content/yolov3/data/images/bus.jpg: 640x480 4 persons, 1 bicycle, 1 bus, 1950.1ms
# image 2/3 /content/yolov3/data/images/kid.jpg: 320x640 3 persons, 1 bicycle, 1 bus, 2 backpacks, 1152.7ms
# image 3/3 /content/yolov3/data/images/zidane.jpg: 384x640 2 persons, 2 ties, 1202.9ms
# ...

# %%
Image(filename='runs/detect/exp7/bus.jpg', width=600)

# %%
Image(filename='runs/detect/exp7/kid.jpg', width=500)

# %%
Image(filename='runs/detect/exp7/zidane.jpg', width=500)
